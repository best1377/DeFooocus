# %% [markdown]
# <a href="https://colab.research.google.com/github/best1377/DeFooocus/blob/main/DeFooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "deafult" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus
# !pip install -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
# Collecting pygit2==1.12.2
#   Using cached pygit2-1.12.2.tar.gz (738 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.12.2) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.23)
# Building wheels for collected packages: pygit2
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygit2 (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for pygit2 (pyproject.toml) ... error
#   ERROR: Failed building wheel for pygit2
# Failed to build pygit2
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pygit2)
# /content
# fatal: destination path 'DeFooocus' already exists and is not an empty directory.
# /content/DeFooocus
# Requirement already satisfied: torchsde==0.2.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 1)) (0.2.6)
# Requirement already satisfied: einops==0.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 2)) (0.8.0)
# Requirement already satisfied: transformers==4.42.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 3)) (4.42.4)
# Requirement already satisfied: safetensors==0.4.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 4)) (0.4.3)
# Requirement already satisfied: accelerate==0.32.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 5)) (0.32.1)
# Requirement already satisfied: pyyaml==6.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 6)) (6.0.1)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 7)) (10.4.0)
# Requirement already satisfied: scipy==1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 8)) (1.14.0)
# Requirement already satisfied: tqdm==4.66.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 9)) (4.66.4)
# Requirement already satisfied: psutil==6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 10)) (6.0.0)
# Requirement already satisfied: pytorch_lightning==2.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 11)) (2.3.3)
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 12)) (2.3.0)
# Requirement already satisfied: gradio==3.41.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 13)) (3.41.2)
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 14)) (1.15.1)
# Requirement already satisfied: opencv-contrib-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 15)) (4.10.0.84)
# Requirement already satisfied: httpx==0.27.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 16)) (0.27.0)
# Requirement already satisfied: onnxruntime==1.18.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 17)) (1.18.1)
# Requirement already satisfied: timm==1.0.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 18)) (1.0.7)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 19)) (1.26.4)
# Requirement already satisfied: tokenizers==0.19.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 20)) (0.19.1)
# Requirement already satisfied: packaging==24.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 21)) (24.1)
# Requirement already satisfied: translators==5.8.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 22)) (5.8.9)
# Requirement already satisfied: rembg==2.0.57 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 23)) (2.0.57)
# Requirement already satisfied: groundingdino-py==0.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 24)) (0.4.0)
# Requirement already satisfied: segment_anything==1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements_versions.txt (line 25)) (1.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from torchsde==0.2.6->-r requirements_versions.txt (line 1)) (2.8.0+cu126)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from torchsde==0.2.6->-r requirements_versions.txt (line 1)) (0.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.42.4->-r requirements_versions.txt (line 3)) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42.4->-r requirements_versions.txt (line 3)) (0.35.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.42.4->-r requirements_versions.txt (line 3)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.42.4->-r requirements_versions.txt (line 3)) (2.32.4)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (2025.3.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (0.15.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf==2.3.0->-r requirements_versions.txt (line 12)) (4.9.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.116.2)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.6.1)
# Requirement already satisfied: gradio-client==0.5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.5.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.11.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.2.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.11.9)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.0.20)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.35.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.41.2->-r requirements_versions.txt (line 13)) (11.0.3)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1->-r requirements_versions.txt (line 14)) (2.0.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.0->-r requirements_versions.txt (line 16)) (4.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.0->-r requirements_versions.txt (line 16)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.0->-r requirements_versions.txt (line 16)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.0->-r requirements_versions.txt (line 16)) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx==0.27.0->-r requirements_versions.txt (line 16)) (1.3.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (1.13.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm==1.0.7->-r requirements_versions.txt (line 18)) (0.23.0+cu126)
# Requirement already satisfied: PyExecJS>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from translators==5.8.9->-r requirements_versions.txt (line 22)) (1.5.1)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from translators==5.8.9->-r requirements_versions.txt (line 22)) (5.4.0)
# Requirement already satisfied: pathos>=0.2.9 in /usr/local/lib/python3.12/dist-packages (from translators==5.8.9->-r requirements_versions.txt (line 22)) (0.3.4)
# Requirement already satisfied: cryptography>=38.0.1 in /usr/local/lib/python3.12/dist-packages (from translators==5.8.9->-r requirements_versions.txt (line 22)) (43.0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from rembg==2.0.57->-r requirements_versions.txt (line 23)) (4.25.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from rembg==2.0.57->-r requirements_versions.txt (line 23)) (4.11.0.86)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from rembg==2.0.57->-r requirements_versions.txt (line 23)) (1.8.2)
# Requirement already satisfied: pymatting in /usr/local/lib/python3.12/dist-packages (from rembg==2.0.57->-r requirements_versions.txt (line 23)) (1.1.14)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.25.2)
# Requirement already satisfied: addict in /usr/local/lib/python3.12/dist-packages (from groundingdino-py==0.4.0->-r requirements_versions.txt (line 24)) (2.4.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.12/dist-packages (from groundingdino-py==0.4.0->-r requirements_versions.txt (line 24)) (0.43.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from groundingdino-py==0.4.0->-r requirements_versions.txt (line 24)) (4.11.0.86)
# Requirement already satisfied: supervision==0.6.0 in /usr/local/lib/python3.12/dist-packages (from groundingdino-py==0.4.0->-r requirements_versions.txt (line 24)) (0.6.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from groundingdino-py==0.4.0->-r requirements_versions.txt (line 24)) (2.0.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx==0.27.0->-r requirements_versions.txt (line 16)) (0.16.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1->-r requirements_versions.txt (line 14)) (2.23)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.4->-r requirements_versions.txt (line 3)) (1.1.10)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg==2.0.57->-r requirements_versions.txt (line 23)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg==2.0.57->-r requirements_versions.txt (line 23)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2025.2)
# Requirement already satisfied: ppft>=1.7.7 in /usr/local/lib/python3.12/dist-packages (from pathos>=0.2.9->translators==5.8.9->-r requirements_versions.txt (line 22)) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pathos>=0.2.9->translators==5.8.9->-r requirements_versions.txt (line 22)) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /usr/local/lib/python3.12/dist-packages (from pathos>=0.2.9->translators==5.8.9->-r requirements_versions.txt (line 22)) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /usr/local/lib/python3.12/dist-packages (from pathos>=0.2.9->translators==5.8.9->-r requirements_versions.txt (line 22)) (0.70.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.41.2->-r requirements_versions.txt (line 13)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from PyExecJS>=1.5.1->translators==5.8.9->-r requirements_versions.txt (line 22)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42.4->-r requirements_versions.txt (line 3)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.42.4->-r requirements_versions.txt (line 3)) (2.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->torchsde==0.2.6->-r requirements_versions.txt (line 1)) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (1.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.14.0->gradio==3.41.2->-r requirements_versions.txt (line 13)) (8.2.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime==1.18.1->-r requirements_versions.txt (line 17)) (10.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==3.41.2->-r requirements_versions.txt (line 13)) (0.48.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->rembg==2.0.57->-r requirements_versions.txt (line 23)) (4.4.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting->rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.60.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg==2.0.57->-r requirements_versions.txt (line 23)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg==2.0.57->-r requirements_versions.txt (line 23)) (2025.9.9)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning==2.3.3->-r requirements_versions.txt (line 11)) (1.20.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting->rembg==2.0.57->-r requirements_versions.txt (line 23)) (0.43.0)
# [DeFooocus] Starting ...
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--attention-split', '--always-high-vram', '--disable-offload-from-vram', '--all-in-fp16', '--theme', 'dark']
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Fooocus version: 0.2
# Total VRAM 15095 MB, total RAM 12975 MB
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using split optimization for cross attention
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://92d6ac2d165f518ee0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using split attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using split attention in VAE
# extra {'cond_stage_model.clip_l.text_projection', 'cond_stage_model.clip_l.logit_scale'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.57 seconds
# Started worker with PID 6482
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://92d6ac2d165f518ee0.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 7387615789878899144
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/DeFooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 436MB/s]
# [Fooocus] Downloading inpainter ...
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/fooocus_inpaint_head.pth" to /content/DeFooocus/models/inpaint/fooocus_inpaint_head.pth
#
# 100% 51.4k/51.4k [00:00<00:00, 38.9MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/inpaint_v26.fooocus.patch" to /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
#
# 100% 1.23G/1.23G [00:09<00:00, 138MB/s]
# [Inpaint] Current inpaint model is /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0], ('/content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch', 1.0)] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 960 keys at weight 1.0.
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.62 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# 2025-10-01 00:14:42.286989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759277682.523009    6548 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759277682.587592    6548 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759277683.049903    6548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759277683.049940    6548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759277683.049944    6548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759277683.049950    6548 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [Prompt Expansion] full naked girl, cute, intricate, highly detailed, elegant, extremely stylish,, divine, glowing, dramatic ambient light, sharp focus, beautiful dynamic, cinematic, modern fine, epic composition, colorful, great colors, perfect, aesthetic, very inspirational,, thought, professional, artistic, color, winning, fair, precious, pretty, romantic, positive, pure, attractive
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1129, 1545), latent is (832, 1152).
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: torch.Size([1, 4, 104, 144])
# Preparation time: 26.40 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 3.19 seconds
#  48% 12/25 [00:19<00:21,  1.63s/it]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 25/25 [00:42<00:00,  1.68s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-10-01/log.html
# Generating and saving time: 48.51 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 74.94 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 5280165858845018161
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] full naked girl, intricate, highly detailed, elegant, lush, light, divine, sharp focus, very slick, artistic, fine, complex, loving, generous, cute, delicate, glowing, color, enhanced, radiant, attractive, colorful, coherent, symmetry, beautiful, friendly, pretty, illuminated, charming, creative, passionate, inspirational, lovely, dramatic ambient background
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (1467, 1545), latent is (960, 1024).
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: torch.Size([1, 4, 120, 128])
# Preparation time: 6.55 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.07 seconds
#  48% 12/25 [00:22<00:24,  1.87s/it]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.50 seconds
# Refiner Swapped
# 100% 25/25 [00:46<00:00,  1.85s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-10-01/log.html
# Generating and saving time: 51.74 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 58.32 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.68 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 968760805774040178
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] full naked girl, very cool, intricate, highly detailed, elegant, fancy, dramatic light, sharp focus, surreal beautiful, open friendly, professional, extremely fine detail, shining bright, iconic, cute, innocent, rich deep complex artistic, great composition, colorful, epic dynamic, atmosphere, full background, amazing delicate, thought, creative, cinematic, positive, pure, attractive
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (1907, 1545), latent is (1152, 896).
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: torch.Size([1, 4, 144, 112])
# Preparation time: 6.56 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.25 seconds
#  48% 12/25 [00:23<00:26,  2.00s/it]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 25/25 [00:48<00:00,  1.95s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-10-01/log.html
# Generating and saving time: 54.81 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 61.40 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 8379621673865295751
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] full naked girl, very detailed, intricate, elegant, highly enhanced, light, divine, dramatic professional, cinematic, artistic, fine detail, vibrant colors, perfect, dynamic color, beautiful, attractive, classy, best,, cute, delicate, pretty, surreal, atmosphere, bright, vivid, ambient, shining, focus, epic, extremely complex, outstanding, luxury, elite
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (2479, 1545), latent is (1280, 768).
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: torch.Size([1, 4, 160, 96])
# Preparation time: 6.18 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.06 seconds
#  48% 12/25 [00:21<00:23,  1.80s/it]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Refiner Swapped
# 100% 25/25 [00:46<00:00,  1.84s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-10-01/log.html
# Generating and saving time: 52.16 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 58.38 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 1061863511774663528
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 25 - 12
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/content/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] full naked girl, modern, intricate, elegant, highly detailed, glowing light, sharp focus, cool composition, holy, transparent glossy divine great magnificent, displayed, warm colors, extremely beautiful,, perfect, fine detail, clear, consistent, artistic, innocent, cinematic, enhanced, deep color, epic, pristine, unique, coherent, shining, symmetry, cute, nice
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (3222, 1545), latent is (1472, 704).
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: torch.Size([1, 4, 184, 88])
# Preparation time: 6.81 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.26 seconds
#  48% 12/25 [00:24<00:26,  2.07s/it]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 25/25 [00:49<00:00,  2.00s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# Image generated with private log at: /content/DeFooocus/outputs/2025-10-01/log.html
# Generating and saving time: 56.67 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 63.52 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7865 <> https://92d6ac2d165f518ee0.gradio.live
